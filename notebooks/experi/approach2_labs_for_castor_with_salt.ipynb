# %% [markdown]
# # First moment up labs organized for Castor upload

# %% [markdown]
# ### This lab layout follows the request of scientists and Castor staff  for upload in Castor
# There is now an additional column to capture true time taken for some labs

# %%
#import libraries

# %%
import os
import sys
from functools import reduce
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import ipywidgets as widgets

sys.path.insert(0, '../../')
from brickstudy import foundation

# %%
### import example lab organization from scientst

# %%
example = pd.read_csv('../../secret_data/Lab_vb_makeda.csv', sep=";")
example.head(4)
# Out:
#   Participant Id Participant Status Site Abbreviation  \
# 0      BRICK_001           Enrolled               ERA
#
#   Participant Creation Date  ERY0  HB0  MCV0  HT0  RDW0  RETI0  ...  ASAT0  \
# 0           12-4-2024 11:39   NaN  NaN   NaN  NaN   NaN    NaN  ...    NaN
#
#    AFOS0  GGT0  CRP0  KREA_U0  TE_U0  TE_U_KR0  ALB_U0  ALB_U_KR0  B120
# 0    NaN   NaN   NaN      NaN    NaN       NaN     NaN        NaN   NaN
#
# [1 rows x 39 columns]

# %%
example.columns
# Out:
# Index(['Participant Id', 'Participant Status', 'Site Abbreviation',
#        'Participant Creation Date', 'ERY0', 'HB0', 'MCV0', 'HT0', 'RDW0',
#        'RETI0', 'LEU0', 'TROMBO0', 'FE0', 'FERT0', 'TRAF0', 'TSAT0', 'ALAT0',
#        'LDH0', 'TBIL0', 'DBIL0', 'KREA0', 'SCHWARTZ_Bedsite0', 'NRCA', 'GRAT0',
#        'FOLZ0', 'UREU0', 'NA0', 'K00', 'VITD0', 'ASAT0', 'AFOS0', 'GGT0',
#        'CRP0', 'KREA_U0', 'TE_U0', 'TE_U_KR0', 'ALB_U0', 'ALB_U_KR0', 'B120'],
#       dtype='object')

# %%
example.shape
# Out:
# (1, 39)

# %% [markdown]
# ### Discussion with scientists over additional columns to adjust for Castor
#
# An additional column will be added

# %% [markdown]
# ### import first measurement moment i.e. baseline labs from 2022,2023 and 2024
# These labs should be named with 1 and uploaded to Castor as repeating data

# %% [markdown]
# # SUPER IMPORTANT
#
# This data has been updated but is all the same measurement moment (zero).

# %%
lab_data = pd.read_csv('../../secret_data/BRICK_lab_data_update_18_03_2024.csv', sep= ';', encoding='latin1')

# %%
lab_data.head(3)
# Out:
#     studieID labdatum_studieID            effectiveDateTime  \
# 0  BRICK-052        2023-04-04  2023-04-04 14:03:22.0000000
# 1  BRICK-052        2023-04-04  2023-04-04 14:03:22.0000000
# 2  BRICK-052        2023-04-04  2023-04-04 14:03:22.0000000
#
#                         issued code_code_original code_display_original  \
# 0  2023-04-04 14:42:56.0000000                CRP                   CRP
# 1  2023-04-04 14:42:56.0000000               DBIL       Dir. Bilirubine
# 2  2023-04-04 14:47:05.0000000               FERT             Ferritine
#
#        hix_code valueQuantity_comparator valueQuantity_value  \
# 0           CRP                        <                 0,6
# 1  Dir. bilirub                      NaN                   8
# 2     Ferritine                      NaN                 115
#
#   valueQuantity_unit valueString  comment interpretation_display  \
# 0               mg/l         NaN  VALAB_V                 Normal
# 1             umol/l         NaN  VALAB_V                   High
# 2               ug/l         NaN  VALAB_V                 Normal
#
#   referenceRange_text specimen_type specimen_type_text  \
# 0                < 10         Bloed       Veneus bloed
# 1                 < 5         Bloed       Veneus bloed
# 2            10 - 140         Bloed       Veneus bloed
#
#                      container_type sample_note
# 0  Heparinebuis Barricor 3.0 ml 18-         NaN
# 1  Heparinebuis Barricor 3.0 ml 18-         NaN
# 2  Heparinebuis Barricor 3.0 ml 18-         NaN

# %%
# print(type(lab_data.effectiveDateTime[1]))
# print((lab_data.effectiveDateTime[1]))

# %%
lab_data['effectiveDateTime'] = pd.to_datetime(lab_data['effectiveDateTime'], format='ISO8601')#format='%Y-%m-%d %H:%M:%S' )
lab_data['effectiveDateTime'] = lab_data['effectiveDateTime'].dt.strftime('%d-%m-%Y') 
# print(type(lab_data.effectiveDateTime[1]))
# print((lab_data.effectiveDateTime[1]))

# %%
len(lab_data.studieID.unique())
# Out:
# 47

# %%
lab_data.studieID.unique()
# Out:
# array(['BRICK-052', 'BRICK-053', 'BRICK-058', 'BRICK-056', 'BRICK-055',
#        'BRICK-054', 'BRICK-027', 'BRICK-031', 'BRICK-028', 'BRICK-024',
#        'BRICK-037', 'BRICK-025', 'BRICK-029', 'BRICK-019', 'BRICK-011',
#        'BRICK-050', 'BRICK-026', 'BRICK-003', 'BRICK-030', 'BRICK-040',
#        'BRICK-002', 'BRICK-014', 'BRICK-004', 'BRICK-042', 'BRICK-047',
#        'BRICK-012', 'BRICK-051', 'BRICK-041', 'BRICK-010', 'BRICK-044',
#        'BRICK-017', 'BRICK-001', 'BRICK-006', 'BRICK-018', 'BRICK-035',
#        'BRICK-049', 'BRICK-016', 'BRICK-015', 'BRICK-048', 'BRICK-023',
#        'BRICK-043', 'BRICK-005', 'BRICK-033', 'BRICK-008', 'BRICK-013',
#        'BRICK-038', 'BRICK-039'], dtype=object)

# %%
lab_data['studieID'] = lab_data['studieID'].astype(str)
lab_data['studieID'] = lab_data['studieID'].str.replace("-", "_")

# %%
lab_data.head(3)
# Out:
#     studieID labdatum_studieID effectiveDateTime                       issued  \
# 0  BRICK_052        2023-04-04        04-04-2023  2023-04-04 14:42:56.0000000
# 1  BRICK_052        2023-04-04        04-04-2023  2023-04-04 14:42:56.0000000
# 2  BRICK_052        2023-04-04        04-04-2023  2023-04-04 14:47:05.0000000
#
#   code_code_original code_display_original      hix_code  \
# 0                CRP                   CRP           CRP
# 1               DBIL       Dir. Bilirubine  Dir. bilirub
# 2               FERT             Ferritine     Ferritine
#
#   valueQuantity_comparator valueQuantity_value valueQuantity_unit valueString  \
# 0                        <                 0,6               mg/l         NaN
# 1                      NaN                   8             umol/l         NaN
# 2                      NaN                 115               ug/l         NaN
#
#    comment interpretation_display referenceRange_text specimen_type  \
# 0  VALAB_V                 Normal                < 10         Bloed
# 1  VALAB_V                   High                 < 5         Bloed
# 2  VALAB_V                 Normal            10 - 140         Bloed
#
#   specimen_type_text                    container_type sample_note
# 0       Veneus bloed  Heparinebuis Barricor 3.0 ml 18-         NaN
# 1       Veneus bloed  Heparinebuis Barricor 3.0 ml 18-         NaN
# 2       Veneus bloed  Heparinebuis Barricor 3.0 ml 18-         NaN

# %% [markdown]
# ### We want  all the patients on thier own line, but not many lines per patient
# We will try to accomplish this by splitting the dataset into each code-code-original i.e. each type of lab taken on the assumption we will almost always have one lab

# %%
lab_data.code_code_original.unique()
# Out:
# array(['CRP', 'DBIL', 'FERT', 'B12', 'FOLZ', 'OSMO_U', 'K', nan, 'FE',
#        'ALB_U', 'TE_U', 'TRAF', 'KREA', 'KREA_U', 'LDH', 'UREU', 'TBIL',
#        'AFOS', 'GGT', 'ASAT', 'ALAT', 'VITD', 'MCV', 'RDW', 'GRAT', 'HB',
#        'HT', 'LEU', 'ERY', 'TROMBO', 'RETI', 'NRCA', 'ICT', 'LIP', 'HEM',
#        'TSAT', 'TE_U_KR', 'ALB_U_KR', 'AB12_Roche', 'SCHWARTZ-Bedsite',
#        'BRICK', 'LORCCA', 'KRBL', 'BGK-MT', 'SCR-MT', 'HPLC HbA2',
#        'HPLC HbF', 'HPLC HbS', 'HPLC HbA0', 'UREU_U', 'CYSC', 'SGEW',
#        'Eiwit', 'ERY_UR', 'LEUKO', 'Ketonen', 'Bilirubine',
#        'Urobilinogeen', 'Nitriet', 'PH', 'GLUC_AO', 'ORD8', 'BAF9', 'PT',
#        'INR', 'FBGC', 'APTT', 'CAC', 'CAG', 'SVRIJ', 'SAC', 'STOT', 'F8S',
#        'ATRO', 'Protrombine-gen_variant', 'FV_Leiden', 'CKD-EPIeGFR',
#        'LENGTH_ORD', 'LENGTH_DAT', 'TNFa', 'FLAM_opti', 'FKAP_opti',
#        'FKALA_UR', 'KPR-MT', 'EX_LUMC', 'BEO1', 'CLIA_IgG_CMV', 'MNEU',
#        'BGL', 'SCR', 'G6PD', 'PIKI', 'F351'], dtype=object)

# %%
codes = lab_data.code_code_original.unique().astype(str)
codes
# Out:
# array(['CRP', 'DBIL', 'FERT', 'B12', 'FOLZ', 'OSMO_U', 'K', 'nan', 'FE',
#        'ALB_U', 'TE_U', 'TRAF', 'KREA', 'KREA_U', 'LDH', 'UREU', 'TBIL',
#        'AFOS', 'GGT', 'ASAT', 'ALAT', 'VITD', 'MCV', 'RDW', 'GRAT', 'HB',
#        'HT', 'LEU', 'ERY', 'TROMBO', 'RETI', 'NRCA', 'ICT', 'LIP', 'HEM',
#        'TSAT', 'TE_U_KR', 'ALB_U_KR', 'AB12_Roche', 'SCHWARTZ-Bedsite',
#        'BRICK', 'LORCCA', 'KRBL', 'BGK-MT', 'SCR-MT', 'HPLC HbA2',
#        'HPLC HbF', 'HPLC HbS', 'HPLC HbA0', 'UREU_U', 'CYSC', 'SGEW',
#        'Eiwit', 'ERY_UR', 'LEUKO', 'Ketonen', 'Bilirubine',
#        'Urobilinogeen', 'Nitriet', 'PH', 'GLUC_AO', 'ORD8', 'BAF9', 'PT',
#        'INR', 'FBGC', 'APTT', 'CAC', 'CAG', 'SVRIJ', 'SAC', 'STOT', 'F8S',
#        'ATRO', 'Protrombine-gen_variant', 'FV_Leiden', 'CKD-EPIeGFR',
#        'LENGTH_ORD', 'LENGTH_DAT', 'TNFa', 'FLAM_opti', 'FKAP_opti',
#        'FKALA_UR', 'KPR-MT', 'EX_LUMC', 'BEO1', 'CLIA_IgG_CMV', 'MNEU',
# 1086  Natrium                      NaN                 141             mmol/l
# 1129  Natrium                      NaN                 141             mmol/l
# 1185  Natrium                      NaN                 140             mmol/l
# 1229  Natrium                      NaN                 139             mmol/l
# 1273  Natrium                      NaN                 137             mmol/l
# 1313  Natrium                      NaN                 139             mmol/l
# 1357  Natrium                      NaN                 141             mmol/l
# 1414  Natrium                      NaN                 141             mmol/l
# 1463  Natrium                      NaN                 140             mmol/l
# 1507  Natrium                      NaN                 143             mmol/l
# 1565  Natrium                      NaN                 139             mmol/l
# 1610  Natrium                      NaN                 140             mmol/l
# 1654  Natrium                      NaN                 141             mmol/l
# 1711  Natrium                      NaN                 142             mmol/l
# 1764  Natrium                      NaN                 140             mmol/l
# 1829  Natrium                      NaN                 140             mmol/l
# 1876  Natrium                      NaN                 140             mmol/l
# 1920  Natrium                      NaN                 138             mmol/l
# 1968  Natrium                      NaN                 143             mmol/l
# 2032  Natrium                      NaN                 139             mmol/l
# 2077  Natrium                      NaN                 138             mmol/l
# 2116  Natrium                      NaN                 136             mmol/l
#
#      valueString  comment interpretation_display referenceRange_text  \
# 7            NaN  VALAB_V                 Normal           136 - 145
# 51           NaN  VALAB_V                 Normal           136 - 145
# 91           NaN  VALAB_V                 Normal           136 - 145
# 134          NaN  VALAB_V                 Normal           136 - 145
# 178          NaN  VALAB_V                 Normal           136 - 145
# 238          NaN  VALAB_V                 Normal           136 - 145
# 308          NaN  VALAB_V                 Normal           136 - 145
# 355          NaN  VALAB_V                 Normal           136 - 145
# 431          NaN  VALAB_V                 Normal           136 - 145
# 477          NaN  VALAB_V                 Normal           136 - 145
# 532          NaN  VALAB_V                 Normal           136 - 145
# 577          NaN  VALAB_V                 Normal           136 - 145
# 624          NaN  VALAB_V                 Normal           136 - 145
# 672          NaN  VALAB_V                 Normal           136 - 145
# 716          NaN  VALAB_V                 Normal           136 - 145
# 760          NaN  VALAB_V                 Normal           136 - 145
# 809          NaN  VALAB_V                 Normal           136 - 145
# 853          NaN  VALAB_V                 Normal           136 - 145
# 896          NaN  VALAB_V                 Normal           136 - 145
# 946          NaN  VALAB_V                 Normal           136 - 145
# 993          NaN  VALAB_V                 Normal           136 - 145
# 1042         NaN  VALAB_V                 Normal           136 - 145
# 1086         NaN  VALAB_V                 Normal           136 - 145
# 1129         NaN  VALAB_V                 Normal           136 - 145
# 1185         NaN  VALAB_V                 Normal           136 - 145
# 1229         NaN  VALAB_V                 Normal           136 - 145
# 1273         NaN  VALAB_V                 Normal           136 - 145
# 1313         NaN  VALAB_V                 Normal           136 - 145
# 1357         NaN  VALAB_V                 Normal           136 - 145
# 1414         NaN  VALAB_V                 Normal           136 - 145
# 1463         NaN  VALAB_V                 Normal           136 - 145
# 1507         NaN  VALAB_V                 Normal           136 - 145
# 1565         NaN  VALAB_V                 Normal           136 - 145
# 1610         NaN  VALAB_V                 Normal           136 - 145
# 1654         NaN  VALAB_V                 Normal           136 - 145
# 1711         NaN  VALAB_V                 Normal           136 - 145
# 1764         NaN  VALAB_V                 Normal           136 - 145
# 1829         NaN  VALAB_V                 Normal           136 - 145
# 1876         NaN  VALAB_V                 Normal           136 - 145
# 1920         NaN  VALAB_V                 Normal           136 - 145
# 1968         NaN  VALAB_V                 Normal           136 - 145
# 2032         NaN  VALAB_V                 Normal           136 - 145
# 2077         NaN  VALAB_V                 Normal           136 - 145
# 2116         NaN  VALAB_V                 Normal           136 - 145
#
#      specimen_type specimen_type_text                       container_type  \
# 7            Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 51           Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 91           Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 134          Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 178          Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 238          Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 308          Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 355          Bloed       Veneus bloed     Heparinebuis Barricor 5.5 ml 18+
# 431          Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 477          Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 532          Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 577          Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 624          Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 672          Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 716          Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 760          Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 809          Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 853          Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 896          Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 946          Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 993          Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 1042         Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 1086         Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 1129         Bloed    Capillair bloed  Heparine microtainer met gel 0.5 ml
# 1185         Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 1229         Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 1273         Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 1313         Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 1357         Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 1414         Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 1463         Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 1507         Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 1565         Bloed       Veneus bloed     Heparinebuis Barricor 5.5 ml 18+
# 1610         Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 1654         Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 1711         Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 1764         Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 1829         Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 1876         Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 1920         Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 1968         Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 2032         Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 2077         Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
# 2116         Bloed       Veneus bloed     Heparinebuis Barricor 3.0 ml 18-
#
#      sample_note
# 7            NaN
# 51           NaN
# 91           NaN
# 134          NaN
# 178          NaN
# 238          NaN
# 308          NaN
# 355          NaN
# 431          NaN
# 477          NaN
# 532          NaN
# 577          NaN
# 624          NaN
# 672          NaN
# 716          NaN
# 760          NaN
# 809          NaN
# 853          NaN
# 896          NaN
# 946          NaN
# 993          NaN
# 1042         NaN
# 1086         NaN
# 1129         NaN
# 1185         NaN
# 1229         NaN
# 1273         NaN
# 1313         NaN
# 1357         NaN
# 1414         NaN
# 1463         NaN
# 1507         NaN
# 1565         NaN
# 1610         NaN
# 1654         NaN
# 1711         NaN
# 1764         NaN
# 1829         NaN
# 1876         NaN
# 1920         NaN
# 1968         NaN
# 2032         NaN
# 2077         NaN
# 2116         NaN

# %% [markdown]
# Again we see all the nans are sodiums. We will transform them to NA

# %%
lab_data['code_code_original'] = lab_data['code_code_original'].fillna('NA')

# %%
codes = lab_data.code_code_original.unique().astype(str)
codes
# Out:
# array(['CRP', 'DBIL', 'FERT', 'B12', 'FOLZ', 'OSMO_U', 'K', 'NA', 'FE',
#        'ALB_U', 'TE_U', 'TRAF', 'KREA', 'KREA_U', 'LDH', 'UREU', 'TBIL',
#        'AFOS', 'GGT', 'ASAT', 'ALAT', 'VITD', 'MCV', 'RDW', 'GRAT', 'HB',
#        'HT', 'LEU', 'ERY', 'TROMBO', 'RETI', 'NRCA', 'ICT', 'LIP', 'HEM',
#        'TSAT', 'TE_U_KR', 'ALB_U_KR', 'AB12_Roche', 'SCHWARTZ-Bedsite',
#        'BRICK', 'LORCCA', 'KRBL', 'BGK-MT', 'SCR-MT', 'HPLC HbA2',
#        'HPLC HbF', 'HPLC HbS', 'HPLC HbA0', 'UREU_U', 'CYSC', 'SGEW',
#        'Eiwit', 'ERY_UR', 'LEUKO', 'Ketonen', 'Bilirubine',
#        'Urobilinogeen', 'Nitriet', 'PH', 'GLUC_AO', 'ORD8', 'BAF9', 'PT',
#        'INR', 'FBGC', 'APTT', 'CAC', 'CAG', 'SVRIJ', 'SAC', 'STOT', 'F8S',
#        'ATRO', 'Protrombine-gen_variant', 'FV_Leiden', 'CKD-EPIeGFR',
#        'LENGTH_ORD', 'LENGTH_DAT', 'TNFa', 'FLAM_opti', 'FKAP_opti',
#        'FKALA_UR', 'KPR-MT', 'EX_LUMC', 'BEO1', 'CLIA_IgG_CMV', 'MNEU',
#        'BGL', 'SCR', 'G6PD', 'PIKI', 'F351'], dtype='<U23')

# %%
#lab_data[lab_data['code_code_original'] == 'nan']

# %%
len(codes)
# Out:
# 93

# %%
## Notte there is a code BRICK...let's examine

# %%
lab_data[lab_data.code_code_original =='BRICK'].head(5)
# Out:
#       studieID labdatum_studieID effectiveDateTime  \
# 43   BRICK_052        2023-04-04        04-04-2023
# 82   BRICK_053        2023-04-04        04-04-2023
# 126  BRICK_058        2023-05-10        10-05-2023
# 170  BRICK_056        2023-05-10        10-05-2023
# 230  BRICK_055        2023-11-17        17-11-2023
#
#                           issued code_code_original code_display_original  \
# 43   2023-04-04 14:10:36.0000000              BRICK                 BRICK
# 82   2023-04-04 13:14:30.0000000              BRICK                 BRICK
# 126  2023-05-10 10:13:45.0000000              BRICK                 BRICK
# 170  2023-05-10 12:23:37.0000000              BRICK                 BRICK
# 230  2023-11-17 12:26:24.0000000              BRICK                 BRICK
#
#          hix_code valueQuantity_comparator valueQuantity_value  \
# 43   Trial/Studie                      NaN                 NaN
# 82   Trial/Studie                      NaN                 NaN
# 126  Trial/Studie                      NaN                 NaN
# 170  Trial/Studie                      NaN                 NaN
# 230  Trial/Studie                      NaN                 NaN
#
#     valueQuantity_unit valueString comment interpretation_display  \
# 43                 NaN   Afgenomen   BRICK                    NaN
# 82                 NaN   Afgenomen   BRICK                    NaN
# 126                NaN   Afgenomen   BRICK                    NaN
# 170                NaN   Afgenomen   BRICK                    NaN
# 230                NaN   Afgenomen   BRICK                    NaN
#
#     referenceRange_text specimen_type specimen_type_text container_type  \
# 43                  NaN         Bloed     Studies/trials      EDTA 6 ml
# 82                  NaN         Bloed     Studies/trials      EDTA 6 ml
# 126                 NaN         Bloed     Studies/trials      EDTA 6 ml
# 170                 NaN         Bloed     Studies/trials      EDTA 6 ml
# 230                 NaN         Bloed     Studies/trials      EDTA 6 ml
#
#     sample_note
# 43          NaN
# 82          NaN
# 126         NaN
# 170         NaN
# 230         NaN

# %%
len(example.columns)
# Out:
# 39

# %% [markdown]
# Scientists not interested in ICT, LIP, HEM, ORD8, BAF9 or EX_LUMC therefore we will drop these values

# %%
lab_data = lab_data.drop(lab_data[lab_data['code_code_original']== 'ICT'].index)
lab_data = lab_data.drop(lab_data[lab_data['code_code_original']== 'LIP'].index)
lab_data = lab_data.drop(lab_data[lab_data['code_code_original']== 'HEM'].index)
lab_data = lab_data.drop(lab_data[lab_data['code_code_original']== 'ORD8'].index)
lab_data = lab_data.drop(lab_data[lab_data['code_code_original']== 'BAF9'].index)
lab_data = lab_data.drop(lab_data[lab_data['code_code_original']== 'EX_LUMC'].index)

# %% [markdown]
# Also according to example there are about 50 other codes they do ont care for. We will drop these here too:

# %%
codes0 = [code + "0" for code in codes]
codes0_set = set(codes0)
expected_set = set(example.columns)
expected_set
# Out:
# {'AFOS0',
#  'ALAT0',
#  'ALB_U0',
#  'ALB_U_KR0',
#  'ASAT0',
#  'B120',
#  'CRP0',
#  'DBIL0',
#  'ERY0',
#  'FE0',
#  'FERT0',
#  'FOLZ0',
#  'GGT0',
#  'GRAT0',
#  'HB0',
#  'HT0',
#  'K00',
#  'KREA0',
#  'KREA_U0',
#  'LDH0',
#  'LEU0',
#  'MCV0',
#  'NA0',
#  'NRCA',
#  'Participant Creation Date',
#  'Participant Id',
#  'Participant Status',
#  'RDW0',
#  'RETI0',
#  'SCHWARTZ_Bedsite0',
#  'Site Abbreviation',
#  'TBIL0',
#  'TE_U0',
#  'TE_U_KR0',
#  'TRAF0',
#  'TROMBO0',
#  'TSAT0',
#  'UREU0',
#  'VITD0'}

# %%
# here we will show columsn we were essentially asked to get rid of
droppable = codes0_set - expected_set
list_droppable = list(droppable)
list_droppable = [code[:-1] for code in list_droppable]
#list_droppable

# %%
# here we can show what we will keep
list_keepable = expected_set
list_keepable =  [code[:-1] for code in list_keepable]
list_keepable
# Out:
# ['HT',
#  'TE_U_KR',
#  'ERY',
#  'ALB_U_KR',
#  'TBIL',
#  'FOLZ',
#  'AFOS',
#  'TRAF',
#  'NA',
#  'Participant Statu',
#  'KREA',
#  'TE_U',
#  'GGT',
#  'Participant I',
#  'CRP',
#  'KREA_U',
#  'B12',
#  'NRC',
#  'FE',
#  'SCHWARTZ_Bedsite',
#  'ASAT',
#  'ALAT',
#  'RDW',
#  'GRAT',
#  'HB',
#  'LDH',
#  'DBIL',
#  'TROMBO',
#  'TSAT',
#  'FERT',
#  'LEU',
#  'ALB_U',
#  'Participant Creation Dat',
#  'MCV',
#  'RETI',
#  'Site Abbreviatio',
#  'K0',
#  'UREU',
#  'VITD']

# %%
list_keepable_amended = ['CRP',
                         'FERT',
                         'TROMBO',
                         'MCV',
                         'K',
                         'FOLZ',
                         'HB',
                         'HT',
                         'UREU',
                         'VITD',
                         'GGT',
                         'ALB_U',
                         'SCHWARTZ-Bedsite',
                         'ASAT',
                         'ERY',
                         'TBIL',
                         'DBIL',
                         'TE_U',
                         'TRAF',
                         'AFOS',
                         'NA',
                         'GRAT',
                         'LDH',
                         'FE',
                         'ALB_U_KR',
                         'B12',
                         'LEU',
                         'RETI',
                         'TSAT',
                         'KREA_U',
                         'ALAT',
                         'KREA',
                         'TE_U_KR',
                         'NRCA',
                         'RDW',]

# %%
# lab_data_baseline = lab_data_baseline[~lab_data_baseline[lab_data_baseline['code_code_original'].isin(list_droppable)]]
# lab_data_baseline
lab_data = lab_data[lab_data['code_code_original'].isin(list_keepable_amended)]

# %%
lab_data['code_code_original'].unique()
# Out:
# array(['CRP', 'DBIL', 'FERT', 'B12', 'FOLZ', 'K', 'NA', 'FE', 'ALB_U',
#        'TE_U', 'TRAF', 'KREA', 'KREA_U', 'LDH', 'UREU', 'TBIL', 'AFOS',
#        'GGT', 'ASAT', 'ALAT', 'VITD', 'MCV', 'RDW', 'GRAT', 'HB', 'HT',
#        'LEU', 'ERY', 'TROMBO', 'RETI', 'NRCA', 'TSAT', 'TE_U_KR',
#        'ALB_U_KR', 'SCHWARTZ-Bedsite'], dtype=object)

# %%
new_codes = list(lab_data['code_code_original'].unique())

# 1998                     Hemoglobine        Hemoglobine
# 1999                     Hemoglobine        Hemoglobine
# 2000                     Hematocriet        Hematocriet
# 2001                     Hematocriet        Hematocriet
# 2002                      Leukocyten         Leukocyten
# 2003                      Leukocyten         Leukocyten
# 2004                     Erytrocyten        Erytrocyten
# 2005                     Erytrocyten        Erytrocyten
# 2006                     Trombocyten        Trombocyten
# 2007                     Trombocyten        Trombocyten
# 2008              Reticulocyten abs.        Retic. abs.
# 2009              Reticulocyten abs.        Retic. abs.
# 2010              Erytroblasten abs.          erytrobl.
# 2011              Erytroblasten abs.          erytrobl.
# 2018          Transferrine saturatie       Transfer.Sat
# 2019           Tot.eiwit urine/kreat        Eiwit/kreat
# 2020       Albumine/Kreatinine ratio         Albu/Kreat
# 2022                SCHWARTZ-Bedsite      Schwartz eGFR
#
#      valueQuantity_comparator valueQuantity_value valueQuantity_unit  \
# 1961                      NaN                 2,6               mg/l
# 1962                      NaN                   8             umol/l
# 1963                      NaN                 112               ug/l
# 1964                      NaN                 279             pmol/l
# 1965                      NaN                26,1             nmol/l
# 1967                      NaN                   4             mmol/l
# 1968                      NaN                 143             mmol/l
# 1969                      NaN                13,1             umol/l
# 1975                      NaN               0,003                g/L
# 1976                      NaN                0,06                g/l
# 1977                      NaN                 2,7                g/l
# 1978                      NaN                  84             umol/l
# 1979                      NaN                10,1             mmol/l
# 1980                      NaN                 397                U/L
# 1984                      NaN                 3,9             mmol/l
# 1985                      NaN                25,3             umol/l
# 1986                      NaN                  72                U/l
# 1987                      NaN                  40                U/l
# 1988                      NaN                  35                U/l
# 1989                      NaN                  27                U/l
# 1992                        <                  10             nmol/L
# 1993                      NaN                  71                 fL
# 1994                      NaN                  71                 fL
# 1995                      NaN                19,1                  %
# 1996                      NaN                19,3                  %
# 1997                      NaN                1,81             10*9/L
# 1998                      NaN                 8,3             mmol/L
# 1999                      NaN                 8,4             mmol/L
# 2000                      NaN                0,37                L/L
# 2001                      NaN                0,37                L/L
# 2002                      NaN                 4,6             10*9/L
# 2003                      NaN                 4,7             10*9/L
# 2004                      NaN                5,18            10*12/L
# 2005                      NaN                5,23            10*12/L
# 2006                      NaN                 124             10*9/L
# 2007                      NaN                 122             10*9/L
# 2008                      NaN               162,1             10*9/L
# 2009                      NaN               161,1             10*9/L
# 2010                      NaN                 NaN                NaN
# 2011                      NaN                 NaN                NaN
# 2018                      NaN               19,25                  %
# 2019                      NaN                5,94            mg/mmol
# 2020                      NaN                 0,3   g/mol Kreatinine
# 2022                      NaN         79,08333333             mL/min
#
#      valueString   comment interpretation_display referenceRange_text  \
# 1961         NaN   VALAB_V                 Normal                < 10
# 1962         NaN   VALAB_V                   High                 < 5
# 1963         NaN   VALAB_V                 Normal            30 - 240
# 1964         NaN       NaN                 Normal           145 - 637
# 1965         NaN       NaN                 Normal                5-40
# 1967         NaN   VALAB_V                 Normal           3.5 - 5.1
# 1968         NaN   VALAB_V                 Normal           136 - 145
# 1969         NaN   VALAB_V                 Normal             10 - 30
# 1975         NaN       NaN                 Normal              < 0.05
# 1976         NaN       NaN                 Normal              < 0.15
# 1977         NaN   VALAB_V                 Normal           2.0 - 3.5
# 1978         NaN   VALAB_V                 Normal             37 - 88
# 1979         NaN       NaN                   High           2.0 - 8.0
# 1980         NaN   VALAB_V                   High               < 380
# 1984         NaN   VALAB_V                 Normal           3.3 - 5.6
# 1985         NaN   VALAB_V                    NaN                 NaN
# 1986         NaN   VALAB_V                 Normal               < 455
# 1987         NaN   VALAB_V                 Normal                < 45
# 1988         NaN   VALAB_V                   High                < 35
# 1989         NaN   VALAB_V                   High                < 26
# 1992         NaN       NaN                    Low            50 - 120
# 1993         NaN  VALAB_c<                    Low             77 - 91
# 1994         NaN   VALAB_V                    Low             77 - 91
# 1995         NaN   VALAB_V                   High         12,0 - 15,0
# 1996         NaN   VALAB_V                   High         12,0 - 15,0
# 1997         NaN   VALAB_V                    NaN                 NaN
# 1998         NaN   VALAB_V                 Normal           6.9 - 9.1
# 1999         NaN   VALAB_V                 Normal           6.9 - 9.1
# 2000         NaN   VALAB_V                 Normal         0.34 - 0.44
# 2001         NaN   VALAB_V                 Normal         0.34 - 0.44
# 2002         NaN   VALAB_V                 Normal           3.8 - 9.8
# 2003         NaN   VALAB_V                 Normal           3.8 - 9.8
# 2004         NaN   VALAB_V                 Normal         4.03 - 5.29
# 2005         NaN   VALAB_V                 Normal         4.03 - 5.29
# 2006         NaN   VALAB_V                    Low           175 - 345
# 2007         NaN   VALAB_V                    Low           175 - 345
# 2008         NaN   VALAB_V                   High             42 - 65
# 2009         NaN   VALAB_V                   High             42 - 65
# 2010         NaN       NaN                    NaN              < 0.01
# 2011         NaN       NaN                    NaN              < 0.01
# 2018         NaN       NaN                    Low               20-45
# 2019         NaN       NaN                 Normal                 <15
# 2020         NaN       NaN                 Normal                  <3
# 2022         NaN       NaN                    Low                > 90
#
#      specimen_type specimen_type_text                    container_type  \
# 1961         Bloed       Veneus bloed  Heparinebuis Barricor 3.0 ml 18-
# 1962         Bloed       Veneus bloed  Heparinebuis Barricor 3.0 ml 18-
# 1963         Bloed       Veneus bloed  Heparinebuis Barricor 3.0 ml 18-
# 1964         Bloed       Veneus bloed           Stolbuis gel 3.5 ml 18-
# 1965         Bloed       Veneus bloed  Heparinebuis Barricor 3.0 ml 18-
# 1967         Bloed       Veneus bloed  Heparinebuis Barricor 3.0 ml 18-
# 1968         Bloed       Veneus bloed  Heparinebuis Barricor 3.0 ml 18-
# 1969         Bloed       Veneus bloed  Heparinebuis Barricor 3.0 ml 18-
# 1975         Urine    Urine midstream                  Urinebuis 6.0 ml
# 1976         Urine    Urine midstream                  Urinebuis 6.0 ml
# 1977         Bloed       Veneus bloed  Heparinebuis Barricor 3.0 ml 18-
# 1978         Bloed       Veneus bloed  Heparinebuis Barricor 3.0 ml 18-
# 1979         Urine    Urine midstream                  Urinebuis 6.0 ml
# 1980         Bloed       Veneus bloed  Heparinebuis Barricor 3.0 ml 18-
# 1984         Bloed       Veneus bloed  Heparinebuis Barricor 3.0 ml 18-
# 1985         Bloed       Veneus bloed  Heparinebuis Barricor 3.0 ml 18-
# 1986         Bloed       Veneus bloed  Heparinebuis Barricor 3.0 ml 18-
# 1987         Bloed       Veneus bloed  Heparinebuis Barricor 3.0 ml 18-
# 1988         Bloed       Veneus bloed  Heparinebuis Barricor 3.0 ml 18-
# 1989         Bloed       Veneus bloed  Heparinebuis Barricor 3.0 ml 18-
# 1992         Bloed       Veneus bloed           Stolbuis gel 3.5 ml 18-
# 1993         Bloed       Veneus bloed                     EDTA 2 ml 18-
# 1994         Bloed       Veneus bloed                     EDTA 2 ml 18-
# 1995         Bloed       Veneus bloed                     EDTA 2 ml 18-
# 1996         Bloed       Veneus bloed                     EDTA 2 ml 18-
# 1997         Bloed       Veneus bloed                     EDTA 2 ml 18-
# 1998         Bloed       Veneus bloed                     EDTA 2 ml 18-
# 1999         Bloed       Veneus bloed                     EDTA 2 ml 18-
# 2000         Bloed       Veneus bloed                     EDTA 2 ml 18-
# 2001         Bloed       Veneus bloed                     EDTA 2 ml 18-
# 2002         Bloed       Veneus bloed                     EDTA 2 ml 18-
# 2003         Bloed       Veneus bloed                     EDTA 2 ml 18-
# 2004         Bloed       Veneus bloed                     EDTA 2 ml 18-
# 2005         Bloed       Veneus bloed                     EDTA 2 ml 18-
# 2006         Bloed       Veneus bloed                     EDTA 2 ml 18-
# 2007         Bloed       Veneus bloed                     EDTA 2 ml 18-
# 2008         Bloed       Veneus bloed                     EDTA 2 ml 18-
# 2009         Bloed       Veneus bloed                     EDTA 2 ml 18-
# 2010         Bloed       Veneus bloed                     EDTA 2 ml 18-
# 2011         Bloed       Veneus bloed                     EDTA 2 ml 18-
# 2018         Bloed       Veneus bloed  Heparinebuis Barricor 3.0 ml 18-
# 2019         Urine    Urine midstream                  Urinebuis 6.0 ml
# 2020         Urine    Urine midstream                  Urinebuis 6.0 ml
# 2022         Bloed       Veneus bloed  Heparinebuis Barricor 3.0 ml 18-
#
#      sample_note
# 1961         NaN
# 1962         NaN
# 1963         NaN
# 1964         NaN
# 1965         NaN
# 1967         NaN
# 1968         NaN
# 1969         NaN
# 1975         NaN
# 1976         NaN
# 1977         NaN
# 1978         NaN
# 1979         NaN
# 1980         NaN
# 1984         NaN
# 1985         NaN
# 1986         NaN
# 1987         NaN
# 1988         NaN
# 1989         NaN
# 1992         NaN
# 1993         NaN
# 1994         NaN
# 1995         NaN
# 1996         NaN
# 1997         NaN
# 1998         NaN
# 1999         NaN
# 2000         NaN
# 2001         NaN
# 2002         NaN
# 2003         NaN
# 2004         NaN
# 2005         NaN
# 2006         NaN
# 2007         NaN
# 2008         NaN
# 2009         NaN
# 2010         NaN
# 2011         NaN
# 2018         NaN
# 2019         NaN
# 2020         NaN
# 2022         NaN

# %%
# #get the brick8 we want by resetting all the times to be the same
brick_8_wanted = lab_data[lab_data['studieID'] == 'BRICK_008']#[lab_data['effectiveDateTime'] == '2022-08-29 10:05:12.0000000']
brick_8_wanted['issued'] = '2022-08-29 10:05:12.0000000'
brick_8_wanted.head(2)
# Out:
# C:\Users\Candace\AppData\Local\Temp\2\ipykernel_4500\1037120095.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   brick_8_wanted['issued'] = '2022-08-29 10:05:12.0000000'
#        studieID labdatum_studieID effectiveDateTime  \
# 1961  BRICK_008        2022-08-29        29-08-2022
# 1962  BRICK_008        2022-08-29        29-08-2022
#
#                            issued code_code_original code_display_original  \
# 1961  2022-08-29 10:05:12.0000000                CRP                   CRP
# 1962  2022-08-29 10:05:12.0000000               DBIL       Dir. Bilirubine
#
#           hix_code valueQuantity_comparator valueQuantity_value  \
# 1961           CRP                      NaN                 2,6
# 1962  Dir. bilirub                      NaN                   8
#
#      valueQuantity_unit valueString  comment interpretation_display  \
# 1961               mg/l         NaN  VALAB_V                 Normal
# 1962             umol/l         NaN  VALAB_V                   High
#
#      referenceRange_text specimen_type specimen_type_text  \
# 1961                < 10         Bloed       Veneus bloed
# 1962                 < 5         Bloed       Veneus bloed
#
#                         container_type sample_note
# 1961  Heparinebuis Barricor 3.0 ml 18-         NaN
# 1962  Heparinebuis Barricor 3.0 ml 18-         NaN

# %% [markdown]
# It did not work the way we wanted because there were repeats. Let's use only one date:

# %%
# brick_8_wanted = lab_data[lab_data['studieID'] == 'BRICK_008'][lab_data['effectiveDateTime'] == '2022-08-29 10:05:12.0000000']
# #brick_8_wanted

# %%
#12
lab_data[lab_data['studieID'] == 'BRICK_012']['effectiveDateTime'].unique()
# Out:
# array(['16-03-2022'], dtype=object)

# %%
#lab_data[lab_data['studieID'] == 'BRICK_012']

# %%
# Here we will assume scientist wants the lab values 4 months later dropped, as not a baseline value
#brick_12_updated = lab_data[lab_data['studieID'] == 'BRICK_012']#[lab_data['effectiveDateTime'].isin(['2022-03-16 15:43:08', '2022-03-16 16:07:41'])]
# we will reset to all the same date
#brick_12_wanted 
# brick_12_updated['effectiveDateTime'] = '2022-03-16 15:43:08'

# %%
#brick_12_urine = lab_data[lab_data['studieID'] == 'BRICK_012'][lab_data['effectiveDateTime'].isin(['2022-07-18 10:02:25'])]

# %%
brick_12_updated.head(2)
# Out:
#        studieID labdatum_studieID effectiveDateTime  \
# 1123  BRICK_012        2022-03-16        16-03-2022
# 1124  BRICK_012        2022-03-16        16-03-2022
#
#                            issued code_code_original code_display_original  \
# 1123  2022-03-16 16:59:12.0000000               DBIL       Dir. Bilirubine
# 1124  2022-03-16 17:03:55.0000000               FERT             Ferritine
#
#           hix_code valueQuantity_comparator valueQuantity_value  \
# 1123  Dir. bilirub                      NaN                  10
# 1124     Ferritine                      NaN                43,9
#
#      valueQuantity_unit valueString  comment interpretation_display  \
# 1123             umol/l         NaN  VALAB_V                   High
# 1124               ug/l         NaN  VALAB_V                 Normal
#
#      referenceRange_text specimen_type specimen_type_text  \
# 1123                 < 5         Bloed    Capillair bloed
# 1124            10 - 140         Bloed    Capillair bloed
#
#                            container_type sample_note
# 1123  Heparine microtainer met gel 0.5 ml         NaN
# 1124  Heparine microtainer met gel 0.5 ml         NaN

# %%
lab_data[lab_data['studieID'] == 'BRICK_021']#['effectiveDateTime'].unique()
# Out:
# Empty DataFrame
# Columns: [studieID, labdatum_studieID, effectiveDateTime, issued, code_code_original, code_display_original, hix_code, valueQuantity_comparator, valueQuantity_value, valueQuantity_unit, valueString, comment, interpretation_display, referenceRange_text, specimen_type, specimen_type_text, container_type, sample_note]
# Index: []

# %%
#brick_21_wanted[brick_21_wanted['effectiveDateTime'] =='2023-06-29 08:47:57']

# %% [markdown]
# # Brick 21 is MISSING!

# %%
## brick_21_wanted = lab_data[lab_data['studieID'] == 'BRICK_021']
#brick_21_wanted[brick_21_wanted['effectiveDateTime'] =='2023-06-29 08:46:36']
#brick_21_wanted[brick_21_wanted['effectiveDateTime'] =='2023-06-29 08:47:57']
#brick_21_wanted[brick_21_wanted['effectiveDateTime'] =='2023-06-29 12:41:15']

# %%
#brick_21_urine = brick_21_wanted[brick_21_wanted['effectiveDateTime'] =='2023-06-29 12:41:15']

# %%
#brick_21_main = brick_21_wanted[brick_21_wanted['effectiveDateTime'] =='2023-06-29 08:47:57']

# %%
#brick_21_wanted = pd.concat([brick_21_urine, brick_21_main])
#brick_21_wanted

# %%
## here we will "redate" them all to match
####brick_21_wanted = lab_data_baseline[lab_data_baseline['studieID'] == 'BRICK_021']
#brick_21_wanted['effectiveDateTime'] = '2023-06-29 08:46:36'
#brick_12_wanted

# %%
lab_data[lab_data['studieID'] == 'BRICK_025']['effectiveDateTime'].unique()
# Out:
# array(['12-09-2022'], dtype=object)

# %%
#brick_25_mcv_wanted = lab_data[lab_data['studieID'] == 'BRICK_025'][lab_data['effectiveDateTime'] == '2022-09-12 15:52:42.0000000']
#brick_25_mcv_wanted

# %%
#brick_25_urine_wanted = lab_data[lab_data['studieID'] == 'BRICK_025'][lab_data['effectiveDateTime'] == '2022-09-12 15:44:02.0000000']
#print(brick_25_urine_wanted.shape)
#brick_25_urine_wanted.

# %%
# #get the brick25 we want by concatenating and  resetting all the times to be the same
# brick_25_wanted = pd.concat([brick_25_mcv_wanted ,brick_25_urine_wanted ])
# print(brick_25_wanted.shape)
# brick_25_wanted['effectiveDateTime'] = '2022-09-12 15:52:42'
# brick_25_wanted.effectiveDateTime.unique()

# %%
## There is anotehr brick -12 in the other dataset!

# %% [markdown]
# These labs are effectively the same date, so we will make them so

# %%
brick_23_wanted = lab_data[lab_data['studieID'] == 'BRICK_023']
# brick_23 seems to have a lot of botched labs they redid
#brick_23_wanted = brick_23_wanted[brick_23_wanted['valueQuantity_value'].notna()]
brick_23_wanted
# Out:
#        studieID labdatum_studieID effectiveDateTime  \
# 1805  BRICK_023        2023-07-17        17-07-2023
# 1806  BRICK_023        2023-07-17        17-07-2023
NaN  Gestold materiaal ontvangen, niets bepaald.      NaN
# 1817             10*9/L                                          NaN  VALAB_V
# 1818                NaN  Gestold materiaal ontvangen, niets bepaald.      NaN
# 1819             10*9/L                                          NaN  VALAB_V
# 1820                NaN  Gestold materiaal ontvangen, niets bepaald.      NaN
# 1821                NaN                                          NaN      NaN
#
#      interpretation_display referenceRange_text specimen_type  \
# 1805                    NaN             71 - 85         Bloed
# 1806                   High             71 - 85         Bloed
# 1807                    NaN         12,0 - 15,0         Bloed
# 1808                   High         12,0 - 15,0         Bloed
# 1809                    NaN           6.4 - 7.9         Bloed
# 1810                    Low           6.4 - 7.9         Bloed
# 1811                    Low         0.31 - 0.38         Bloed
# 1812                    NaN          4.3 - 11.4         Bloed
# 1813                   High          4.3 - 11.4         Bloed
# 1814                    NaN         3.84 - 4.97         Bloed
# 1815                    Low         3.84 - 4.97         Bloed
# 1816                    NaN           189 - 403         Bloed
# 1817                 Normal           189 - 403         Bloed
# 1818                    NaN             36 - 68         Bloed
# 1819                   High             36 - 68         Bloed
# 1820                    NaN              < 0.01         Bloed
# 1821                    NaN              < 0.01         Bloed
#
#      specimen_type_text           container_type sample_note
# 1805    Capillair bloed  EDTA microtainer 0.5 ml         NaN
# 1806       Veneus bloed            EDTA 2 ml 18-         NaN
# 1807    Capillair bloed  EDTA microtainer 0.5 ml         NaN
# 1808       Veneus bloed            EDTA 2 ml 18-         NaN
# 1809    Capillair bloed  EDTA microtainer 0.5 ml         NaN
# 1810       Veneus bloed            EDTA 2 ml 18-         NaN
# 1811       Veneus bloed            EDTA 2 ml 18-         NaN
# 1812    Capillair bloed  EDTA microtainer 0.5 ml         NaN
# 1813       Veneus bloed            EDTA 2 ml 18-         NaN
# 1814    Capillair bloed  EDTA microtainer 0.5 ml         NaN
# 1815       Veneus bloed            EDTA 2 ml 18-         NaN
# 1816    Capillair bloed  EDTA microtainer 0.5 ml         NaN
# 1817       Veneus bloed            EDTA 2 ml 18-         NaN
# 1818    Capillair bloed  EDTA microtainer 0.5 ml         NaN
# 1819       Veneus bloed            EDTA 2 ml 18-         NaN
# 1820    Capillair bloed  EDTA microtainer 0.5 ml         NaN
# 1821       Veneus bloed            EDTA 2 ml 18-         NaN

# %%
lab_data[lab_data['studieID'] == 'BRICK_055']['effectiveDateTime'].unique()
# Out:
# array(['17-11-2023'], dtype=object)

# %% [markdown]
# These labs are effectively the same date, so we will make them so

# %%
#lab_data[lab_data['studieID'] == 'BRICK_055']

# %% [markdown]
# We must choose as the same labs were ralen more than once.

# %%
# brick_55_wanted = lab_data[lab_data['studieID'] == 'BRICK_055']
# brick_55_wanted = brick_55_wanted[brick_55_wanted['effectiveDateTime'].isin(['2023-11-17 11:35:12.0000000', '2023-11-17 12:20:40.0000000'])]
# # we also have different issue times, we will get rid of that
# brick_55_wanted['issued'] = '17-11-2023'

# %%
#brick_55_wanted.tail(2)

# %%
lab_data[lab_data['studieID'] == 'BRICK_052']['effectiveDateTime'].unique()
# Out:
# array(['04-04-2023'], dtype=object)

# %%
# brick_52_wanted = lab_data[lab_data['studieID'] == 'BRICK_052']
# # brick_52_wanted['effectiveDateTime'] = '2023-04-04 14:03:22.0000000'
# # brick_52_wanted['issued'] = '2023-04-04 14:42:56.0000000'
# for column in brick_52_wanted.columns:
#     print(brick_52_wanted[column].unique())

# %%
#now let's drop all of them, then append back on what we want
# lab_data_no_ = lab_data.drop(lab_data[lab_data['studieID'] == 'BRICK_012'].index)
# lab_data_no_ = lab_data_no_.drop(lab_data_no_[lab_data_no_['studieID'] == 'BRICK_008'].index)
# lab_data_no_ = lab_data_no_.drop(lab_data_no_[lab_data_no_['studieID'] == 'BRICK_021'].index)
# lab_data_no_ = lab_data_no_.drop(lab_data_no_[lab_data_no_['studieID'] == 'BRICK_025'].index)
# lab_data_no_ = lab_data_no_.drop(lab_data_no_[lab_data_no_['studieID'] == 'BRICK_023'].index)
# lab_data_no_ = lab_data_no_.drop(lab_data_no_[lab_data_no_['studieID'] == 'BRICK_055'].index)
# lab_data_no_ = lab_data_no_.drop(lab_data_no_[lab_data_no_['studieID'] == 'BRICK_052'].index)
# lab_data_no_ = lab_data_no_.drop(lab_data_no_[lab_data_no_['studieID'] == 'BRICK_058'].index)
#lab_data_no_ = lab_data_no_.drop(lab_data_no_[lab_data_no_['studieID'] == 'BRICK_012'].index)

# %%
lab_data_no_ = lab_data

# %%
lab_data_no_.studieID.unique()
# Out:
# array(['BRICK_052', 'BRICK_053', 'BRICK_058', 'BRICK_056', 'BRICK_055',
#        'BRICK_054', 'BRICK_027', 'BRICK_031', 'BRICK_028', 'BRICK_024',
#        'BRICK_037', 'BRICK_025', 'BRICK_029', 'BRICK_019', 'BRICK_011',
#        'BRICK_050', 'BRICK_026', 'BRICK_003', 'BRICK_030', 'BRICK_040',
#        'BRICK_002', 'BRICK_014', 'BRICK_004', 'BRICK_042', 'BRICK_047',
#        'BRICK_012', 'BRICK_051', 'BRICK_041', 'BRICK_010', 'BRICK_044',
#        'BRICK_017', 'BRICK_001', 'BRICK_006', 'BRICK_018', 'BRICK_035',
#        'BRICK_049', 'BRICK_016', 'BRICK_015', 'BRICK_048', 'BRICK_023',
#        'BRICK_043', 'BRICK_005', 'BRICK_033', 'BRICK_008', 'BRICK_013',
#        'BRICK_038', 'BRICK_039'], dtype=object)

# %%
len(lab_data_no_.studieID.unique())
# Out:
# 47

# %%
len(lab_data_no_.effectiveDateTime.unique())
# Out:
# 26

# %%
# brick_58_wanted = lab_data_no_[lab_data_no_['studieID'] == 'BRICK_058']
# brick_58_wanted['effectiveDateTime']= '2023-05-10 09:45:08.0000000'
# brick_58_wanted['issued']= '2023-05-10 10:41:43.0000000'

# %%
#lab_data_no_[lab_data_no_['effectiveDateTime'] == '2023-05-10 09:45:08.0000000']

# %%
#lab_data_no_

# %%
# lab_data = pd.concat([lab_data_no_, brick_8_wanted,  brick_12_updated, brick_25_wanted, brick_52_wanted, brick_55_wanted, brick_23_wanted, brick_58_wanted])
# lab_data.shape

# %%
#brick_55_wanted

# %%
list_of_data_frames = []
for code in new_codes:
    prenames = ["code_code_original", code]
    frame_name = "_".join(prenames)
    #print(frame_name)
    frame_name = lab_data[lab_data['code_code_original'] == code]
    frame_name = frame_name.add_suffix(code)
    frame_name = frame_name.rename(columns= {frame_name.columns[0]:'studieID'})
    list_of_data_frames.append(frame_name)

# %%
len(list_of_data_frames)
# Out:
# 35

# %%
len(new_codes)
# Out:
# 35

# %% [markdown]
# Let's look at an example:

# %%
list_of_data_frames[0].head(3)
# Out:
#      studieID labdatum_studieIDCRP effectiveDateTimeCRP  \
# 0   BRICK_052           2023-04-04           04-04-2023
# 45  BRICK_053           2023-04-04           04-04-2023
# 84  BRICK_058           2023-05-10           10-05-2023
#
#                       issuedCRP code_code_originalCRP  \
# 0   2023-04-04 14:42:56.0000000                   CRP
# 45  2023-04-04 13:54:04.0000000                   CRP
# 84  2023-05-10 10:41:43.0000000                   CRP
#
#    code_display_originalCRP hix_codeCRP valueQuantity_comparatorCRP  \
# 0                       CRP         CRP                           <
# 45                      CRP         CRP                         NaN
# 84                      CRP         CRP                           <
#
#    valueQuantity_valueCRP valueQuantity_unitCRP valueStringCRP commentCRP  \
# 0                     0,6                  mg/l            NaN    VALAB_V
# 45                    4,2                  mg/l            NaN    VALAB_V
# 84                    0,6                  mg/l            NaN    VALAB_V
#
#    interpretation_displayCRP referenceRange_textCRP specimen_typeCRP  \
# 0                     Normal                   < 10            Bloed
# 45                    Normal                   < 10            Bloed
# 84                    Normal                   < 10            Bloed
#
#    specimen_type_textCRP                 container_typeCRP sample_noteCRP
# 0           Veneus bloed  Heparinebuis Barricor 3.0 ml 18-            NaN
# 45          Veneus bloed  Heparinebuis Barricor 3.0 ml 18-            NaN
# 84          Veneus bloed  Heparinebuis Barricor 3.0 ml 18-            NaN

# %%
list_of_data_frames[1].head(3)
# Out:
#      studieID labdatum_studieIDDBIL effectiveDateTimeDBIL  \
# 1   BRICK_052            2023-04-04            04-04-2023
# 46  BRICK_053            2023-04-04            04-04-2023
# 85  BRICK_058            2023-05-10            10-05-2023
#
#                      issuedDBIL code_code_originalDBIL  \
# 1   2023-04-04 14:42:56.0000000                   DBIL
# 46  2023-04-04 13:55:36.0000000                   DBIL
# 85  2023-05-10 10:41:42.0000000                   DBIL
#
#    code_display_originalDBIL  hix_codeDBIL valueQuantity_comparatorDBIL  \
# 1            Dir. Bilirubine  Dir. bilirub                          NaN
# 46           Dir. Bilirubine  Dir. bilirub                          NaN
# 85           Dir. Bilirubine  Dir. bilirub                          NaN
#
#    valueQuantity_valueDBIL valueQuantity_unitDBIL valueStringDBIL  \
# 1                        8                 umol/l             NaN
# 46                       4                 umol/l             NaN
# 85                       9                 umol/l             NaN
#
#                               commentDBIL interpretation_displayDBIL  \
# 1                                 VALAB_V                       High
# 46  VALAB_V Vals verlaagd a.g.v. hemolyse                     Normal
# 85                                VALAB_V                       High
#
#    referenceRange_textDBIL specimen_typeDBIL specimen_type_textDBIL  \
# 1                      < 5             Bloed           Veneus bloed
# 46                     < 5             Bloed           Veneus bloed
# 85                     < 5             Bloed           Veneus bloed
#
#                   container_typeDBIL sample_noteDBIL
# 1   Heparinebuis Barricor 3.0 ml 18-             NaN
# 46  Heparinebuis Barricor 3.0 ml 18-             NaN
# 85  Heparinebuis Barricor 3.0 ml 18-             NaN

# %%
list_of_data_frames[1].shape
# Out:
# (44, 18)

# %% [markdown]
# So far so good, we have a frame with in the example above the DBIL. We then tried to do a big reduction; but it produced repeaters

# %%
semi_final_df = reduce(lambda left,right: pd.merge(left,right, on=['studieID'], how='outer'), list_of_data_frames)

# %%
semi_final_df.shape
# Out:
# (1355, 596)

# %%
semi_final_df.head(5)
# Out:
#     studieID labdatum_studieIDCRP effectiveDateTimeCRP  \
# 0  BRICK_001           2022-06-20           20-06-2022
# 1  BRICK_002           2022-06-20           20-06-2022
# 2  BRICK_003           2022-06-20           20-06-2022
# 3  BRICK_004           2022-07-04           04-07-2022
# 4  BRICK_005           2022-12-14           14-12-2022
#
#                      issuedCRP code_code_originalCRP code_display_originalCRP  \
# 0  2022-06-20 16:09:38.0000000                   CRP                      CRP
# 1  2022-06-20 15:47:23.0000000                   CRP                      CRP
# 2  2022-06-20 15:48:02.0000000                   CRP                      CRP
# 3  2022-07-04 16:24:38.0000000                   CRP                      CRP
# 4  2022-12-14 11:19:57.0000000                   CRP                      CRP
#
#   hix_codeCRP valueQuantity_comparatorCRP valueQuantity_valueCRP  \
# 0         CRP                         NaN                    0,8
# 1         CRP                         NaN                    0,8
# 2         CRP                           <                    0,6
# 3         CRP                         NaN                     11
# 4         CRP                         NaN                    5,2
#
#   valueQuantity_unitCRP  ... valueQuantity_valueSCHWARTZ-Bedsite  \
# 0                  mg/l  ...                         145,7329268
# 1                  mg/l  ...                         91,88730159
# 2                  mg/l  ...                                 NaN
# 3                  mg/l  ...                         110,3488372
# 4                  mg/l  ...                                 NaN
#
#   valueQuantity_unitSCHWARTZ-Bedsite valueStringSCHWARTZ-Bedsite  \
# 0                             mL/min                         NaN
# 1                             mL/min                         NaN
# 2                                NaN                Niet bepaald
# 3                             mL/min                         NaN
# 4                                NaN                Niet bepaald
#
#                              commentSCHWARTZ-Bedsite  \
# 0                                                NaN
# 1                                                NaN
# 2  Meest recent gedocumenteerde lengte ouder dan ...
# 3                                                NaN
# 4  Meest recent gedocumenteerde lengte ouder dan ...
#
#   interpretation_displaySCHWARTZ-Bedsite referenceRange_textSCHWARTZ-Bedsite  \
# 0                                 Normal                                > 90
# 1                                 Normal                                > 90
# 2                                    NaN                                > 90
# 3                                 Normal                                > 90
# 4                                    NaN                                > 90
#
#   specimen_typeSCHWARTZ-Bedsite specimen_type_textSCHWARTZ-Bedsite  \
# 0                         Bloed                       Veneus bloed
# 1                         Bloed                       Veneus bloed
# 2                         Bloed                       Veneus bloed
# 3                         Bloed                       Veneus bloed
# 4                         Bloed                       Veneus bloed
#
#      container_typeSCHWARTZ-Bedsite sample_noteSCHWARTZ-Bedsite
# 0  Heparinebuis Barricor 3.0 ml 18-                         NaN
# 1  Heparinebuis Barricor 3.0 ml 18-                         NaN
# 2  Heparinebuis Barricor 3.0 ml 18-                         NaN
# 3  Heparinebuis Barricor 3.0 ml 18-                         NaN
# 4  Heparinebuis Barricor 3.0 ml 18-                         NaN
#
# [5 rows x 596 columns]

# %%
for studieID in semi_final_df.studieID:
    print(studieID)
# Out:
# BRICK_001
# BRICK_002
# BRICK_003
# BRICK_004
# BRICK_005
# BRICK_006
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_008
# BRICK_010
# BRICK_011
# BRICK_012
# BRICK_013
# BRICK_014
# BRICK_015
# BRICK_016
# BRICK_017
# BRICK_018
# BRICK_019
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_023
# BRICK_024
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_025
# BRICK_026
# BRICK_027
# BRICK_028
# BRICK_029
# BRICK_030
# BRICK_031
# BRICK_033
# BRICK_035
# BRICK_037
# BRICK_038
# BRICK_039
# BRICK_040
# BRICK_041
# BRICK_042
# BRICK_043
# BRICK_044
# BRICK_047
# BRICK_048
# BRICK_049
# BRICK_050
# BRICK_051
# BRICK_052
# BRICK_053
# BRICK_054
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_055
# BRICK_056
# BRICK_058

# %%
# now we need to change the columns names to those expoected by scientist
for  f in semi_final_df.columns:
    print(f)

# %%
list_keepable_amended_with_id = ["valueQuantity_value" + code for code in list_keepable_amended]
# [code + "0" for code in codes]
list_keepable_amended_with_id = list_keepable_amended_with_id + ['studieID'] + ['effectiveDateTimeCRP']
list_keepable_amended_with_id

# %%
final_amend = ['studieID',
               'effectiveDateTimeCRP',
               'valueQuantity_valueCRP',
                 'valueQuantity_valueFERT',
                 'valueQuantity_valueTROMBO',
                 'valueQuantity_valueMCV',
                 'valueQuantity_valueK',
                 'valueQuantity_valueFOLZ',
                 'valueQuantity_valueHB',
                 'valueQuantity_valueHT',
                 'valueQuantity_valueUREU',
                 'valueQuantity_valueVITD',
                 'valueQuantity_valueGGT',
                 'valueQuantity_valueALB_U',
                 'valueQuantity_valueSCHWARTZ-Bedsite',
                 'valueQuantity_valueASAT',
                 'valueQuantity_valueERY',
                 'valueQuantity_valueTBIL',
                 'valueQuantity_valueDBIL',
                 'valueQuantity_valueTE_U',
                 'valueQuantity_valueTRAF',
                 'valueQuantity_valueAFOS',
                 'valueQuantity_valueNA',
                 'valueQuantity_valueGRAT',
                 'valueQuantity_valueLDH',
                 'valueQuantity_valueFE',
                 'valueQuantity_valueALB_U_KR',
                 'valueQuantity_valueB12',
                 'valueQuantity_valueLEU',
                 'valueQuantity_valueRETI',
                 'valueQuantity_valueTSAT',
                 'valueQuantity_valueKREA_U',
                 'valueQuantity_valueALAT',
                 'valueQuantity_valueKREA',
                 'valueQuantity_valueTE_U_KR',
                 'valueQuantity_valueNRCA',
                 'valueQuantity_valueRDW', ]

# %%
filtered = semi_final_df[final_amend]
filtered.columns

# %%
columns_dictionary = {'studieID':'Participant ID',
                      'effectiveDateTimeCRP': 'blood_date_time',
                      'valueQuantity_valueCRP':'CRP0',  
                      'valueQuantity_valueFERT':'FERT0',
                      'valueQuantity_valueTROMBO':'TROMBO0',
                      'valueQuantity_valueMCV':'MCV0',
                      'valueQuantity_valueK':'K0',
                      'valueQuantity_valueFOLZ':'FOLZ0',
                      'valueQuantity_valueHB':'HB0',  
                      'valueQuantity_valueHT':'HT0',
                      'valueQuantity_valueUREU':'UREU0',  
                      'valueQuantity_valueVITD':'VITD0',
                      'valueQuantity_valueGGT':'GGT0',  
                      'valueQuantity_valueALB_U':'ALB_U0',
                      'valueQuantity_valueSCHWARTZ-Bedsite':'SCHWARTZ-Bedsite0',  
                      'valueQuantity_valueASAT':'ASAT0',
                      'valueQuantity_valueERY':'ERY0',  
                      'valueQuantity_valueTBIL':'TBIL0',
                      'valueQuantity_valueDBIL':'DBIL0',  
                      'valueQuantity_valueTE_U':'TE_U0',
                      'valueQuantity_valueTRAF':'TRAF0',  
                      'valueQuantity_valueNA':'NA0',
                      'valueQuantity_valueAFOS':'AFOS0',
                      'valueQuantity_valueGRAT':'GRAT0',  
                      'valueQuantity_valueLDH':'LDH0',
                      'valueQuantity_valueFE':'FE0',  
                      'valueQuantity_valueALB_U_KR':'ALB_U_KR0',
                      'valueQuantity_valueB12':'B120',  
                      'valueQuantity_valueLEU':'LEU0',
                      'valueQuantity_valueRETI':'RETI0',  
                      'valueQuantity_valueTSAT':'TSAT0',
                      'valueQuantity_valueKREA_U':'KREA_U0',  
                      'valueQuantity_valueALAT':'ALAT0',
                      'valueQuantity_valueKREA':'KREA0',  
                      'valueQuantity_valueTE_U_KR':'TE_U_KR0',
                      'valueQuantity_valueNRCA':'NRCA0',  
                      'valueQuantity_valueRDW':'RDW0'}
filtered = filtered.rename(columns = columns_dictionary)
filtered

# %%
#fix missing date times
filtered[filtered.blood_date_time.isna()]

# %%
filtered = filtered.rename(columns={'K0':'K00'})
filtered.columns

# %%
filtered['Participant Status']= 'Enrolled'

# %%
filtered['Site Abbreviation'] = 'ERA'

# %% [markdown]
# No idea where to get Participant Creation Date from ...it isn'tteh same as lab date, so let's leave it out.

# %%
filtered.shape

# %%
## Now we need to get 21 an the other 12 from the labs we filtered in the other notebook
twelve_and_21 =pd.read_csv('../../secret_data/castor_with_salt_baseline_labs.csv', index_col=0)

# %%
twelve_and_21_relevant = twelve_and_21[twelve_and_21['Participant ID'].isin(['BRICK_012','BRICK_021'])]
twelve_and_21_relevant = twelve_and_21_relevant[1:]
twelve_and_21_relevant
twenty_relevant = twelve_and_21_relevant[twelve_and_21_relevant['Participant ID'].isin(['BRICK_021'])]
twelve_relevant = twelve_and_21_relevant[twelve_and_21_relevant['Participant ID'].isin(['BRICK_012'])]
twenty_relevant['blood_date_time'] = '2023-06-29 08:47:57' 
twelve_relevant['blood_date_time'] = '2022-07-18 10:02:25'

# %%
twelve_relevant

# %%
final = pd.concat([filtered, twelve_relevant, twenty_relevant])
final

# %%
final['visit_name_column'] = 'T0'
final.head(3)

# %%
final['custom_name_column'] = 'baseline_lab'
final.head(3)

# %%
final = final[['Participant ID','visit_name_column', 'custom_name_column','blood_date_time', 'CRP0', 'FERT0', 'TROMBO0', 'MCV0',
       'K00', 'FOLZ0', 'HB0', 'HT0', 'UREU0', 'VITD0', 'GGT0', 'ALB_U0',
       'SCHWARTZ-Bedsite0', 'ASAT0', 'ERY0', 'TBIL0', 'DBIL0', 'TE_U0',
       'TRAF0', 'AFOS0', 'NA0', 'GRAT0', 'LDH0', 'FE0', 'ALB_U_KR0', 'B120',
       'LEU0', 'RETI0', 'TSAT0', 'KREA_U0', 'ALAT0', 'KREA0', 'TE_U_KR0',
       'NRCA0', 'RDW0', 'Participant Status', 'Site Abbreviation',]]

# %%
final.to_csv('../../secret_data/castor_with_salt_first_measurement_moment_labsv1.csv')

# %%
final.head()

# %%
final['date_lab_test'] = final['blood_date_time']
print(type(final['date_lab_test'][1]))

# %%
final.columns

# %%
hacked_away_time = final[['Participant ID', 'visit_name_column', 'custom_name_column','CRP0', 'FERT0', 'TROMBO0', 'MCV0', 'K00', 'FOLZ0',
       'HB0', 'HT0', 'UREU0', 'VITD0', 'GGT0', 'ALB_U0', 'SCHWARTZ-Bedsite0',
       'ASAT0', 'ERY0', 'TBIL0', 'DBIL0', 'TE_U0', 'TRAF0', 'AFOS0', 'NA0',
       'GRAT0', 'LDH0', 'FE0', 'ALB_U_KR0', 'B120', 'LEU0', 'RETI0', 'TSAT0',
       'KREA_U0', 'ALAT0', 'KREA0', 'TE_U_KR0', 'NRCA0', 'RDW0',
       'Participant Status', 'Site Abbreviation',]]

# %%
hacked_away_time.to_csv('../../secret_data/experihack.csv')

# %%
DD-MM-YYYY
